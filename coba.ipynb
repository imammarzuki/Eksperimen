# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_html("https://imammarzuki.online/Administrator&password=imammarzuki/")
data[0]
# Out:
#         No  User ID                             Daerah Asal  Usia  \
# 0        1        1  Luar kota Batu tetapi masih 1 provinsi    36
# 1        2        2  Luar kota Batu tetapi masih 1 provinsi    33
# 2        3        3  Luar kota Batu tetapi masih 1 provinsi    45
# 3        4        4  Luar kota Batu tetapi masih 1 provinsi    41
# 4        5        5  Luar kota Batu tetapi masih 1 provinsi    33
# ...    ...      ...                                     ...   ...
# 1486  1487     1488  Luar kota Batu tetapi masih 1 provinsi    12
# 1487  1488     1489  Luar kota Batu tetapi masih 1 provinsi    12
# 1488  1489     1490  Luar kota Batu tetapi masih 1 provinsi    12
# 1489  1490     1491  Luar kota Batu tetapi masih 1 provinsi    12
# 1490  1491     1492  Luar kota Batu tetapi masih 1 provinsi    20
#
#      Jenis Kelamin          Hobi Status Pernikahan Pendidikan Terakhir  \
# 0        Laki-Laki    Travelling     Sudah Menikah                  S2
# 1        Perempuan  Hobi Lainnya     Sudah Menikah                  S2
# 2        Laki-Laki    Travelling     Sudah Menikah                  S2
# 3        Perempuan    Travelling     Sudah Menikah               S1/D4
# 4        Laki-Laki  Hobi Lainnya     Sudah Menikah                  S2
# ...            ...           ...               ...                 ...
# 1486     Laki-Laki  Hobi Lainnya     Belum Menikah                  S1
# 1487     Perempuan  Hobi Lainnya     Belum Menikah                  S1
# 1488     Laki-Laki    Travelling     Belum Menikah                  S1
# 1489     Perempuan  Hobi Lainnya     Belum Menikah                  S1
# 1490     Laki-Laki    Travelling     Belum Menikah       SMA/Sederajat
#
#               Pekerjaan Frekuensi Berwisata Setahun Terakhir  ... BNS  \
# 0       Karyawan Swasta                    lebih dari 3 kali  ...   4
# 1                   PNS                    lebih dari 3 kali  ...   5
# 2                   PNS                               3 kali  ...   5
# 3            Wiraswasta                               3 kali  ...   5
# 4                   PNS                    lebih dari 3 kali  ...   3
# ...                 ...                                  ...  ...  ..
# 1486  Pelajar/Mahasiswa                    lebih dari 3 kali  ...   5
# 1487  Pelajar/Mahasiswa                    lebih dari 3 kali  ...   5
# 1488  Pelajar/Mahasiswa                               2 kali  ...   4
# 1489  Pelajar/Mahasiswa                    lebih dari 3 kali  ...   5
# 1490  Pelajar/Mahasiswa                    lebih dari 3 kali  ...   5
#
#      Eco Green Park Alun-alun Kota Batu Kusuma Agro Cangar  Coban Talun  \
# 0                 4                   3           4      3            3
# 1                 5                   4           5      4            5
# 2                 5                   4           5      5            5
# 3                 5                   5           5      5            5
# 4                 0                   5           3      0            5
# ...             ...                 ...         ...    ...          ...
# 1486              4                   3           4      3            3
# 1487              5                   4           5      4            5
# 1488              4                   3           4      3            3
# 1489              4                   4           5      4            5
# 1490              5                   5           5      4            5
#
#       Pemandian Songgoriti  Coban Rais  Predator Fun Park      Tindakan
# 0                        3           3                  4  Edit | Hapus
# 1                        5           5                  5  Edit | Hapus
# 2                        5           5                  5  Edit | Hapus
# 3                        5           5                  5  Edit | Hapus
# 4                        5           5                  0  Edit | Hapus
# ...                    ...         ...                ...           ...
# 1486                     3           3                  3  Edit | Hapus
# 1487                     5           3                  5  Edit | Hapus
# 1488                     3           3                  3  Edit | Hapus
# 1489                     5           3                  5  Edit | Hapus
# 1490                     5           5                  4  Edit | Hapus
#
# [1491 rows x 30 columns]

# %%
data[0].columns
# Out:
# Index(['No', 'User ID', 'Daerah Asal', 'Usia', 'Jenis Kelamin', 'Hobi',
#        'Status Pernikahan', 'Pendidikan Terakhir', 'Pekerjaan',
#        'Frekuensi Berwisata Setahun Terakhir',
#        'Jenis Wisata yang Sering Dikunjungi', 'Alasan Berwisata',
#        'Teman Perjalanan', 'Kendaraan yang Digunakan', 'Menyediakan Anggaran',
#        'Jatim Park 1', 'Jatim Park 2', 'Jatim Park 3', 'Museum Angkut',
#        'Selecta', 'BNS', 'Eco Green Park', 'Alun-alun Kota Batu',
#        'Kusuma Agro', 'Cangar', 'Coban Talun', 'Pemandian Songgoriti',
#        'Coban Rais', 'Predator Fun Park', 'Tindakan'],
#       dtype='object')

# %%
data1=data[0].rename({"Frekuensi Berwisata Setahun Terakhir":"Frekuensi Berwisata","Jenis Wisata yang Sering Dikunjungi":"Jenis Wisata","Kendaraan yang Digunakan":"Kendaraan"},axis=1)
data1.columns
# Out:
# Index(['No', 'User ID', 'Daerah Asal', 'Usia', 'Jenis Kelamin', 'Hobi',
#        'Status Pernikahan', 'Pendidikan Terakhir', 'Pekerjaan',
#        'Frekuensi Berwisata', 'Jenis Wisata', 'Alasan Berwisata',
#        'Teman Perjalanan', 'Kendaraan', 'Menyediakan Anggaran', 'Jatim Park 1',
#        'Jatim Park 2', 'Jatim Park 3', 'Museum Angkut', 'Selecta', 'BNS',
#        'Eco Green Park', 'Alun-alun Kota Batu', 'Kusuma Agro', 'Cangar',
#        'Coban Talun', 'Pemandian Songgoriti', 'Coban Rais',
#        'Predator Fun Park', 'Tindakan'],
#       dtype='object')

# %%
df=data1.drop(["Tindakan"], axis=1)
df.columns
# Out:
# Index(['No', 'User ID', 'Daerah Asal', 'Usia', 'Jenis Kelamin', 'Hobi',
#        'Status Pernikahan', 'Pendidikan Terakhir', 'Pekerjaan',
#        'Frekuensi Berwisata', 'Jenis Wisata', 'Alasan Berwisata',
#        'Teman Perjalanan', 'Kendaraan', 'Menyediakan Anggaran', 'Jatim Park 1',
#        'Jatim Park 2', 'Jatim Park 3', 'Museum Angkut', 'Selecta', 'BNS',
#        'Eco Green Park', 'Alun-alun Kota Batu', 'Kusuma Agro', 'Cangar',
#        'Coban Talun', 'Pemandian Songgoriti', 'Coban Rais',
#        'Predator Fun Park'],
#       dtype='object')

# %%
df
# Out:
#         No  User ID                             Daerah Asal  Usia  \
# 0        1        1  Luar kota Batu tetapi masih 1 provinsi    36
# 1        2        2  Luar kota Batu tetapi masih 1 provinsi    33
# 2        3        3  Luar kota Batu tetapi masih 1 provinsi    45
# 3        4        4  Luar kota Batu tetapi masih 1 provinsi    41
# 4        5        5  Luar kota Batu tetapi masih 1 provinsi    33
# ...    ...      ...                                     ...   ...
# 1486  1487     1488  Luar kota Batu tetapi masih 1 provinsi    12
# 1487  1488     1489  Luar kota Batu tetapi masih 1 provinsi    12
# 1488  1489     1490  Luar kota Batu tetapi masih 1 provinsi    12
# 1489  1490     1491  Luar kota Batu tetapi masih 1 provinsi    12
# 1490  1491     1492  Luar kota Batu tetapi masih 1 provinsi    20
#
#      Jenis Kelamin          Hobi Status Pernikahan Pendidikan Terakhir  \
# 0        Laki-Laki    Travelling     Sudah Menikah                  S2
# 1        Perempuan  Hobi Lainnya     Sudah Menikah                  S2
# 2        Laki-Laki    Travelling     Sudah Menikah                  S2
# 3        Perempuan    Travelling     Sudah Menikah               S1/D4
# 4        Laki-Laki  Hobi Lainnya     Sudah Menikah                  S2
# ...            ...           ...               ...                 ...
# 1486     Laki-Laki  Hobi Lainnya     Belum Menikah                  S1
# 1487     Perempuan  Hobi Lainnya     Belum Menikah                  S1
# 1488     Laki-Laki    Travelling     Belum Menikah                  S1
# 1489     Perempuan  Hobi Lainnya     Belum Menikah                  S1
# 1490     Laki-Laki    Travelling     Belum Menikah       SMA/Sederajat
#
#               Pekerjaan Frekuensi Berwisata  ... Selecta BNS Eco Green Park  \
# 0       Karyawan Swasta   lebih dari 3 kali  ...       4   4              4
# 1                   PNS   lebih dari 3 kali  ...       5   5              5
# 2                   PNS              3 kali  ...       5   5              5
# 3            Wiraswasta              3 kali  ...       5   5              5
# 4                   PNS   lebih dari 3 kali  ...       5   3              0
# ...                 ...                 ...  ...     ...  ..            ...
# 1486  Pelajar/Mahasiswa   lebih dari 3 kali  ...       4   5              4
# 1487  Pelajar/Mahasiswa   lebih dari 3 kali  ...       5   5              5
# 1488  Pelajar/Mahasiswa              2 kali  ...       4   4              4
# 1489  Pelajar/Mahasiswa   lebih dari 3 kali  ...       5   5              4
# 1490  Pelajar/Mahasiswa   lebih dari 3 kali  ...       5   5              5
#
#      Alun-alun Kota Batu Kusuma Agro  Cangar  Coban Talun  \
# 0                      3           4       3            3
# 1                      4           5       4            5
# 2                      4           5       5            5
# 3                      5           5       5            5
# 4                      5           3       0            5
# ...                  ...         ...     ...          ...
# 1486                   3           4       3            3
# 1487                   4           5       4            5
# 1488                   3           4       3            3
# 1489                   4           5       4            5
# 1490                   5           5       4            5
#
#       Pemandian Songgoriti  Coban Rais  Predator Fun Park
# 0                        3           3                  4
# 1                        5           5                  5
# 2                        5           5                  5
# 3                        5           5                  5
# 4                        5           5                  0
# ...                    ...         ...                ...
# 1486                     3           3                  3
# 1487                     5           3                  5
# 1488                     3           3                  3
# 1489                     5           3                  5
# 1490                     5           5                  4
#
# [1491 rows x 29 columns]

# %%
# Preprocessing
le = LabelEncoder()
df['Daerah Asal'] = le.fit_transform(df['Daerah Asal'])
df['Jenis Kelamin'] = le.fit_transform(df['Jenis Kelamin'])
df['Hobi'] = le.fit_transform(df['Hobi'])
df['Status Pernikahan'] = le.fit_transform(df['Status Pernikahan'])
df['Pendidikan Terakhir'] = le.fit_transform(df['Pendidikan Terakhir'])
df['Pekerjaan'] = le.fit_transform(df['Pekerjaan'])
df['Frekuensi Berwisata'] = le.fit_transform(df['Frekuensi Berwisata'])
df['Jenis Wisata'] = le.fit_transform(df['Jenis Wisata'])
df['Alasan Berwisata'] = le.fit_transform(df['Alasan Berwisata'])
df['Teman Perjalanan'] = le.fit_transform(df['Teman Perjalanan'])
df['Kendaraan'] = le.fit_transform(df['Kendaraan'])
df['Menyediakan Anggaran'] = le.fit_transform(df['Menyediakan Anggaran'])

scaler = MinMaxScaler()
df[['Usia']] = scaler.fit_transform(df[['Usia']])

# %%
# Features and labels
features = df[['User ID','Daerah Asal', 'Usia', 'Jenis Kelamin', 'Hobi', 'Status Pernikahan', 'Pendidikan Terakhir', 'Pekerjaan', 'Frekuensi Berwisata', 'Jenis Wisata', 'Alasan Berwisata', 'Teman Perjalanan', 'Menyediakan Anggaran']]
labels = df[['Jatim Park 1', 'Jatim Park 2', 'Jatim Park 3', 'Museum Angkut', 'Selecta', 'BNS', 'Eco Green Park', 'Alun-alun Kota Batu', 'Kusuma Agro', 'Cangar', 'Coban Talun', 'Pemandian Songgoriti', 'Coban Rais', 'Predator Fun Park']]

# %%
# Content-Based Filtering
def predict_ratings(user_features, labels):
    predictions = []
    for i in range(labels.shape[1]):
        model = LinearRegression()
        model.fit(user_features, labels.iloc[:, i])
        predictions.append(model.predict(user_features))
    return np.array(predictions).T

predictions = predict_ratings(features, labels)
true_ratings = labels.values

# Evaluasi
mae = mean_absolute_error(true_ratings, predictions)
rmse = mean_squared_error(true_ratings, predictions, squared=False)

# Untuk metrik classification, kita perlu binarize ratings
threshold = 3.5
true_binary = (true_ratings > threshold).astype(int)
pred_binary = (predictions > threshold).astype(int)

accuracy = accuracy_score(true_binary.flatten(), pred_binary.flatten())
precision = precision_score(true_binary.flatten(), pred_binary.flatten(), average='weighted')
recall = recall_score(true_binary.flatten(), pred_binary.flatten(), average='weighted')
f1 = f1_score(true_binary.flatten(), pred_binary.flatten(), average='weighted')

# Output hasil evaluasi
print(f'MAE: {mae}')
print(f'RMSE: {rmse}')
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1-Score: {f1}')
# Out:
# MAE: 0.16841603173282757
# RMSE: 0.37013482865134145
# Accuracy: 0.9643096675289834
# Precision: 0.9643521103235138
# Recall: 0.9643096675289834
# F1-Score: 0.9638384223742263
